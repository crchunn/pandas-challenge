# %%
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
import numpy as np

# %%
heroes = "../Resources/purchase_data.csv"

# %%
heroes_df = pd.read_csv(heroes)
heroes_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
heroes_df = heroes_df.rename(columns={'Purchase ID': 'PID', 'Item ID': 'Item', 'Item Name': 'Name'})
heroes_df.head()
# Out:
#    PID             SN  Age Gender  Item  \
# 0    0        Lisim78   20   Male   108
# 1    1    Lisovynya38   40   Male   143
# 2    2     Ithergue48   24   Male    92
# 3    3  Chamassasya86   24   Male   100
# 4    4      Iskosia90   23   Male   131
#
#                                         Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
Players = heroes_df.SN.nunique() #count of unique columns
#heroes_df.rename['SN'] = Players
#print (Players)
Player_Summary_df = pd.DataFrame({'Player Count': [Players]})
Player_Summary_df
# Out:
#    Player Count
# 0           576

# %%
Item_Count = heroes_df.Item.nunique()
print(Item_Count)
# Out:
# 179

# %%
Purchase_ID = heroes_df.PID.nunique()
Purchase_ID
# Out:
# 780

# %%
average_price = heroes_df['Price'].mean()
print(average_price)
# Out:
# 3.050987179487176

# %%
Total_Revenue = heroes_df['Price'].sum()
print(Total_Revenue)
# Out:
# 2379.77

# %%
Purchasing_Analysis_df = pd.DataFrame({'Number of Unique Items': [Item_Count], 
                                       'Average Price': [average_price], 
                                       'Number of Purchases': [Purchase_ID], 
                                     'Total Revenue': [Total_Revenue] })
Purchasing_Analysis_df
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     179       3.050987                  780        2379.77

# %%
heroes_df.SN.value_counts() #counting the Screen Names
# Out:
# Lisosia93        5
# Iral74           4
# Idastidru52      4
# Silaera56        3
# Aina42           3
#                 ..
# Eosrirgue62      1
# Chamirraya83     1
# Sundadarla27     1
# Thrientossa55    1
# Haerithp41       1
# Name: SN, Length: 576, dtype: int64

# %%
#heroes_df.index

# %%
heroes_df.Gender.nunique()
# Out:
# 3

# %%
g_count = heroes_df.groupby('Gender')
print(g_count['SN'].count())
# Out:
# Gender
# Female                   113
# Male                     652
# Other / Non-Disclosed     15
# Name: SN, dtype: int64

# %%
gender_count = heroes_df.drop_duplicates(['SN', 'Gender'])
gender_count.groupby('Gender').SN.size()

print(gender_count['Gender'].count())
# Out:
# 576

# %%
pd.DataFrame(heroes_df.SN.value_counts()) #curious out how many purchases each person made because the amount of purchases
#isn't singular. Some screen names have purchased multiple times
# Out:
#                SN
# Lisosia93       5
# Iral74          4
# Idastidru52     4
# Silaera56       3
# Aina42          3
# ...            ..
# Eosrirgue62     1
# Chamirraya83    1
# Sundadarla27    1
# Thrientossa55   1
# Haerithp41      1
#
# [576 rows x 1 columns]

# %%
#heroes_df.loc[heroes_df.SN == "Lisosia93"]
# to find direct info on a player

# %%
gcount = heroes_df['Gender'].value_counts()
print(gcount)
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
#gcount = heroes_df.loc[heroes_df.Gender == 'Male'].sum
#print(gcount)
count = heroes_df['Gender'].value_counts()/Players*100
count
# Out:
# Male                     113.194444
# Female                    19.618056
# Other / Non-Disclosed      2.604167
# Name: Gender, dtype: float64

# %%
#gender_group = heroes_df.groupby('Gender')
#gender_purchase_df = pd.DataFrame(gender_group['Price'].value_counts())
#gender_purchase_df.append = pd.DataFrame(gender_group['Item'].value_counts())
#gender_purchase_df.head
gender_group = heroes_df.groupby(['Gender'])['Price'].sum()
gender_group
# Out:
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64

# %%
gender_group/gcount
# Out:
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# dtype: float64

# %%
gender_gravg = heroes_df.groupby(['Gender'])['Price'].mean()
gender_gravg
#average purchase
# Out:
# Gender
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# Name: Price, dtype: float64

# %%
Purchase_Gen_Analysis_df = pd.DataFrame({'Gender': [gcount],
                                     'Average Purchase Price': [gender_gravg],
                                     'Total Purchase Value': [gender_group]})

Purchase_Gen_Analysis_df
# Out:
#                                               Gender  \
# 0  Male                     652
# Female           ...
#
#                               Average Purchase Price  \
# 0  Gender
# Female                   3.203009
# Male ...
#
#                                 Total Purchase Value
# 0  Gender
# Female                    361.94
# Male  ...

# %%
#gcount_df = pd.DataFrame.heroes_df.SN
#pd.DataFrame(heroes_df.Gender.value_counts())
heroes_df.drop_duplicates('SN', keep=False)
#heroes_df.iloc.rename('Total Players').to_frame()
#curious about the types of gender and trying to figure out how it plays into the data gathering
# Out:
#      PID               SN  Age                 Gender  Item  \
# 1      1      Lisovynya38   40                   Male   143
# 2      2       Ithergue48   24                   Male    92
# 3      3    Chamassasya86   24                   Male   100
# 4      4        Iskosia90   23                   Male   131
# 6      6        Itheria73   36                   Male   169
# 8      8        Undjask33   22                   Male    21
# 13    13      Assjaskan73   22                   Male     4
# 15    15        Lisassa64   21                 Female    98
# 16    16        Lisirra25   20                   Male    40
# 19    19        Chamalo71   30                   Male    89
# 20    20     Iathenudil29   20                   Male    57
# 21    21    Phiarithdeu40   20                   Male   168
# 25    25        Lisirra87   29                   Male   178
# 27    27          Eusri44    7                   Male    96
# 28    28           Aela59   21                   Male   119
# ...

# %%
#demographics

# %%
age_buy = heroes_df.groupby(["Age"])
bins = (0, 9.9, 14, 19, 24, 29, 34, 39, 100)
group_name = ["<10","10-14","15-19","20-24","25-29","30-34","35-39","40+"]
age_demo_df = pd.cut([age_buy], bins, labels=group_name, include_lowest=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-1b0d100e6727> in <module>
#       2 bins = (0, 9.9, 14, 19, 24, 29, 34, 39, 100)
#       3 group_name = ["<10","10-14","15-19","20-24","25-29","30-34","35-39","40+"]
# ----> 4 age_demo_df = pd.cut([age_buy], bins, labels=group_name, include_lowest=True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     204
#     205     original = x
# --> 206     x = _preprocess_for_cut(x)
#     207     x, dtype = _coerce_to_type(x)
#     208
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\tile.py in _preprocess_for_cut(x)
#     553         x = np.asarray(x)
#     554     if x.ndim != 1:
# --> 555         raise ValueError("Input array must be 1 dimensional")
#     556
#     557     return x
#
# ...

# %%
heroes_df.info()
#what kinds of info it is

# %%
Gender_df = pd.DataFrame({"Unique Genders": Male = "Male", Female = "Female", Other = "Other" index = [0]})
